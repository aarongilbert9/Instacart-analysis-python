# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'OneDrive/Desktop/Instacart basket Analysis 12-2024'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared data', 'ords_prods_merge.pkl'))

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_count  order_dow  order_hour_of_day  \
# 0   2539329        1            1          2                  8
# 1   2539329        1            1          2                  8
# 2   2539329        1            1          2                  8
# 3   2539329        1            1          2                  8
# 4   2539329        1            1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both
#
#                               product_name  aisle_id  department_id     prices
# ...

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
ords_prods_merge.loc[(ords_prods_merge['prices'] <= 15) & (ords_prods_merge['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] <= 5, 'price_range_loc'] = 'low-range product'

# %%
ords_prods_merge['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid-range product     21865987
# low-range product     10126321
# High-range product      412551
# Name: count, dtype: int64

# %%
ords_prods_merge['order_dow'].value_counts(dropna = False)
# Out:
# order_dow
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
result = []

for value in ords_prods_merge["order_dow"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
ords_prods_merge['busiest_day'] = result

# %%
ords_prods_merge['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %%
#  Checking to make sure the 2 new columns were added correctly
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_count  order_dow  order_hour_of_day  \
# 0   2539329        1            1          2                  8
# 1   2539329        1            1          2                  8
# 2   2539329        1            1          2                  8
# 3   2539329        1            1          2                  8
# 4   2539329        1            1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both
#
#                               product_name  aisle_id  department_id  \
# ...

# %% [markdown]
# Exercise 4.7 task

# %% [markdown]
# question 2

# %%
# check for buisest days
ords_prods_merge['order_dow'].value_counts(dropna = False)
# Out:
# order_dow
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
# 0 and 1 are the busiest days
## create a new label for both days

ords_prods_merge.loc[ords_prods_merge['order_dow'].isin([0, 1]), 'busiest_days'] = 'Busiest Days'

# %%
# 3 and 4 are the slowest days
## create a new label for both days

ords_prods_merge.loc[ords_prods_merge['order_dow'].isin([3, 4]), 'busiest_days'] = 'Slowest Days'

# %%
# create label for regular days

ords_prods_merge.loc[ords_prods_merge['order_dow'].isin([6, 2, 5]), 'busiest_days'] = 'Regularly busy Days'

# %% [markdown]
# question 3
# check values in this new column

# %%
# check busiest_day
ords_prods_merge['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %%
# check busiest days
ords_prods_merge['busiest_days'].value_counts(dropna = False)
# Out:
# busiest_days
# Regularly busy Days    12916111
# Busiest Days           11864412
# Slowest Days            7624336
# Name: count, dtype: int64

# %%
# checking both columns for equal counts
ords_prods_merge['busiest_day'].shape == ords_prods_merge['busiest_days'].shape
# Out:
# True

# %%
# check output
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_count  order_dow  order_hour_of_day  \
# 0   2539329        1            1          2                  8
# 1   2539329        1            1          2                  8
# 2   2539329        1            1          2                  8
# 3   2539329        1            1          2                  8
# 4   2539329        1            1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both
#
#                               product_name  aisle_id  department_id  \
# ...

# %%
ords_prods_merge.tail()
# Out:
#           order_id  user_id  order_count  order_dow  order_hour_of_day  \
# 32404854   2977660   206209           13          1                 12
# 32404855   2977660   206209           13          1                 12
# 32404856   2977660   206209           13          1                 12
# 32404857   2977660   206209           13          1                 12
# 32404858   2977660   206209           13          1                 12
#
#           days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 32404854                     7.0       14197                  5          1
# 32404855                     7.0       38730                  6          0
# 32404856                     7.0       31477                  7          0
# 32404857                     7.0        6567                  8          0
# 32404858                     7.0       22920                  9          0
#
#          _merge                           product_name  aisle_id  \
# ...

# %% [markdown]
# Question 3 Answers
# As we might expect, the busiest_days value counts are much closer together than the busiest_day value counts because we are now grouping the days in groups of 2 or 3 days as opposed 1 or 5 days. We also see that the total counts are equal for both as we would expect.

# %% [markdown]
# question 4

# %%
# identify buisest hours of the day
ords_prods_merge['order_hour_of_day'].value_counts(dropna = False)
# Out:
# order_hour_of_day
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %%
# create empty list and for-loop to populate list with busiest time of day labels

busiest_hour = []

for value in ords_prods_merge['order_hour_of_day']:
    if value == 10 or value == 11 or value == 14 or value == 15 or value == 13 or value == 12 or value == 16 or value == 9:
        busiest_hour.append("Most orders")
    elif value == 17 or value == 8 or value == 18 or value == 19 or value == 20 or value == 7 or value == 21 or value == 22:
        busiest_hour.append("Average orders")
    else:
        busiest_hour.append("Fewest orders")

# %%
# create a column in DF labeled busiest period of day
ords_prods_merge['busiest_period_of_day'] = busiest_hour

# %%
# check output
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_count  order_dow  order_hour_of_day  \
# 0   2539329        1            1          2                  8
# 1   2539329        1            1          2                  8
# 2   2539329        1            1          2                  8
# 3   2539329        1            1          2                  8
# 4   2539329        1            1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both
#
#                               product_name  aisle_id  department_id  \
# ...

# %%
# print frequency
ords_prods_merge['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# busiest_period_of_day
# Most orders       21118071
# Average orders     9997651
# Fewest orders      1289137
# Name: count, dtype: int64

# %%
# export data frame
ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared data', 'ords_prods_merge_updated.pkl'))
