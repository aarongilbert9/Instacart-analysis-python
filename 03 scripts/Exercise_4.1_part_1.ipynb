# %%
# importing libraries 

import pandas as pd
import numpy as np
import os
import gc

# %%
path = r'OneDrive/Desktop/Instacart basket Analysis 12-2024'

# %%
# importing customers data set
customers = pd.read_csv(os.path.join(path, '02 Data', 'original', 'customers.csv'), index_col = False)

# %%
customers.head()
# Out:
#    user_id first_name last_name  gender       state  age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants marital_status  income
# 0             3        married  165665
# 1             0         single   59285
# 2             2        married   99568
# 3             0         single   42049
# 4             1        married   40374

# %%
customers.shape
# Out:
# (206209, 10)

# %%
customers.describe()
# Out:
#              user_id            age   n_dependants         income
# count  206209.000000  206209.000000  206209.000000  206209.000000
# mean   103105.000000      49.501646       1.499823   94632.852548
# std     59527.555167      18.480962       1.118433   42473.786988
# min         1.000000      18.000000       0.000000   25903.000000
# 25%     51553.000000      33.000000       0.000000   59874.000000
# 50%    103105.000000      49.000000       1.000000   93547.000000
# 75%    154657.000000      66.000000       3.000000  124244.000000
# max    206209.000000      81.000000       3.000000  593901.000000

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   user_id         206209 non-null  int64
#  1   first_name      206209 non-null  object
#  2   last_name       206209 non-null  object
#  3   gender          206209 non-null  object
#  4   state           206209 non-null  object
#  5   age             206209 non-null  int64
#  6   date_joined     206209 non-null  object
#  7   n_dependants    206209 non-null  int64
#  8   marital_status  206209 non-null  object
#  9   income          206209 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 15.7+ MB

# %% [markdown]
# Step 4
# Wrangling data

# %% [markdown]
# Renaming columns so it follows the same format

# %%
# Rename First Name as first_name
customers.rename(columns = {'First Name' : 'first_name'}, inplace = True)

# %%
# Rename Surnam as last_name
customers.rename(columns = {'Surnam' : 'last_name'}, inplace = True)

# %%
# Rename Gender as gender
customers.rename(columns = {'Gender' : 'gender'}, inplace = True)

# %%
# Rename STATE as state
customers.rename(columns = {'STATE' : 'state'}, inplace = True)

# %%
# Rename Age as age
customers.rename(columns = {'Age' : 'age'}, inplace = True)

# %%
# Rename fam_status as marital_status
customers.rename(columns = {'fam_status' : 'marital_status'}, inplace = True)

# %%
# Checking to make sure the changes were made correctly
customers.columns
# Out:
# Index(['user_id', 'first_name', 'last_name', 'gender', 'state', 'age',
#        'date_joined', 'n_dependants', 'marital_status', 'income'],
#       dtype='object')

# %% [markdown]
# No columns need to be dropped right now, but I could drop first and last name if memory issues occur.

# %% [markdown]
# Step 5 - Complete the fundamental data quality and consistency checks

# %%
# Checking missing values
customers.isnull().sum()
# Out:
# user_id           0
# first_name        0
# last_name         0
# gender            0
# state             0
# age               0
# date_joined       0
# n_dependants      0
# marital_status    0
# income            0
# dtype: int64

# %% [markdown]
# No missing values

# %%
# Checking duplicates
df_dups = customers[customers.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [user_id, first_name, last_name, gender, state, age, date_joined, n_dependants, marital_status, income]
# Index: []

# %% [markdown]
# No dups

# %%
customers.head(100)
# Out:
#     user_id  first_name last_name  gender       state  age date_joined  \
# 0     26711     Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1     33890    Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2     65803     Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3    125935    Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4    130797         Ann   Gilmore  Female    Maryland   26    1/1/2017
# ..      ...         ...       ...     ...         ...  ...         ...
# 95    86389     Stephen   Murillo    Male     Vermont   69    1/1/2017
# 96   102956       Kathy  Mitchell  Female    Missouri   78    1/1/2017
# 97   180919  Jacqueline     Roach  Female    Nebraska   21    1/1/2017
# 98    74155       Karen      Berg  Female     Alabama   33    1/1/2017
# 99    96166         NaN   Oconnor    Male    Oklahoma   51    1/1/2017
#
#     n_dependants                    marital_status  income
# 0              3                           married  165665
# 1              0                            single   59285
# 2              2                           married   99568
# 3              0                            single   42049
# 4              1                           married   40374
# ..           ...                               ...     ...
# 95             3                           married   66800
# 96             1                           married   96314
# 97             3  living with parents and siblings   56831
# 98             3                           married   95285
# 99             1                           married  155673
#
# [100 rows x 10 columns]

# %%
# Let's check again the mixed data-type
for col in customers.columns.tolist():
  weird = (customers[[col]].map(type) != customers[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (customers[weird]) > 0:
    print (col)

# %%
# changing first name column to a string
customers['first_name'] = customers['first_name'].astype('str')

# %%
# Let's check again the mixed data-type
for col in customers.columns.tolist():
  weird = (customers[[col]].map(type) != customers[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (customers[weird]) > 0:
    print (col)

# %%
customers.head()
# Out:
#    user_id first_name last_name  gender       state  age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants marital_status  income
# 0             3        married  165665
# 1             0         single   59285
# 2             2        married   99568
# 3             0         single   42049
# 4             1        married   40374

# %% [markdown]
# Step 6 - Combine your customer data with the rest of your prepared Instacart data

# %%
# Import the rest of prepared Instacart data
ords_prods_merge =pd.read_pickle(os.path.join(path, '02 Data', 'Prepared data', 'orders_products_merged_grouped.pkl'))

# %%
ords_prods_merge.shape
# Out:
# (32404859, 23)

# %%
# Merge ords_prods_merge with customers data
ords_prods_customers_merge = pd.merge(ords_prods_merge, customers, on = 'user_id', how = 'inner')

# %%
ords_prods_customers_merge.shape
# Out:
# (32404859, 32)

# %%
ords_prods_customers_merge.head(200)
# Out:
#      order_id  user_id  order_count  order_dow  order_hour_of_day  \
# 0     2539329        1            1          2                  8
# 1     2539329        1            1          2                  8
# 2     2539329        1            1          2                  8
# 3     2539329        1            1          2                  8
# 4     2539329        1            1          2                  8
# ..        ...      ...          ...        ...                ...
# 195   1402090        2           11          1                 10
# 196   1402090        2           11          1                 10
# 197   1402090        2           11          1                 10
# 198   1402090        2           11          1                 10
# 199   1402090        2           11          1                 10
#
#      days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                       NaN         196                  1          0
# 1                       NaN       14084                  2          0
# 2                       NaN       12427                  3          0
# 3                       NaN       26088                  4          0
# 4                       NaN       26405                  5          0
# ..                      ...         ...                ...        ...
# 195                    30.0       32792                  1          1
# 196                    30.0        4071                  2          0
# 197                    30.0       19051                  3          1
# 198                    30.0       19156                  4          1
# 199                    30.0       18523                  5          1
#
#                                           product_name  ...  \
# 0                                                 Soda  ...
# 1              Organic Unsweetened Vanilla Almond Milk  ...
# 2                                  Original Beef Jerky  ...
# 3                           Aged White Cheddar Popcorn  ...
# 4                     XL Pick-A-Size Paper Towel Rolls  ...
# ..                                                 ...  ...
# 195                     Chipotle Beef & Pork Realstick  ...
# 196                    Organic Lemongrass Ginger Ramen  ...
# 197               Pita Chips, Simply Naked, Party Size  ...
# 198                          Fat Free Blueberry Yogurt  ...
# 199  Total 2% All Natural Greek Strained Yogurt wit...  ...
#
#       order_frequency_flag  first_name  last_name  gender    state age  \
# 0    Non-frequent customer       Linda     Nguyen  Female  Alabama  31
# 1    Non-frequent customer       Linda     Nguyen  Female  Alabama  31
# 2    Non-frequent customer       Linda     Nguyen  Female  Alabama  31
# 3    Non-frequent customer       Linda     Nguyen  Female  Alabama  31
# 4    Non-frequent customer       Linda     Nguyen  Female  Alabama  31
# ..                     ...         ...        ...     ...      ...  ..
# 195       Regular customer       Norma    Chapman  Female   Alaska  68
# 196       Regular customer       Norma    Chapman  Female   Alaska  68
# 197       Regular customer       Norma    Chapman  Female   Alaska  68
# 198       Regular customer       Norma    Chapman  Female   Alaska  68
# 199       Regular customer       Norma    Chapman  Female   Alaska  68
#
#     date_joined  n_dependants marital_status  income
# 0     2/17/2019             3        married   40423
# 1     2/17/2019             3        married   40423
# 2     2/17/2019             3        married   40423
# 3     2/17/2019             3        married   40423
# 4     2/17/2019             3        married   40423
# ..          ...           ...            ...     ...
# 195    7/4/2017             3        married   64940
# 196    7/4/2017             3        married   64940
# 197    7/4/2017             3        married   64940
# 198    7/4/2017             3        married   64940
# 199    7/4/2017             3        married   64940
#
# [200 rows x 32 columns]

# %%
# Step 8 - Export this new dataframe as a pickle file
ords_prods_customers_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_customers_merge.pkl'))
